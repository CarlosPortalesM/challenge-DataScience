# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
ingreso_total_tienda1 = tienda['Precio'].sum()
print(f'El ingreso total de la tienda 1 es {ingreso_total_tienda1}')
# Out:
# El ingreso total de la tienda 1 es 1150880400.0

# %%
ingreso_total_tienda2 = tienda2['Precio'].sum()
print(f'El ingreso total de la tienda 2 es {ingreso_total_tienda2}')
# Out:
# El ingreso total de la tienda 2 es 1116343500.0

# %%
ingreso_total_tienda3 = tienda3['Precio'].sum()
print(f'El ingreso total de la tienda 3 es {ingreso_total_tienda3}')
# Out:
# El ingreso total de la tienda 3 es 1098019600.0

# %%
ingreso_total_tienda4 = tienda4['Precio'].sum()
print(f'El ingreso total de la tienda 4 es {ingreso_total_tienda4}')
# Out:
# El ingreso total de la tienda 4 es 1038375700.0

# %%
ingresos_totales = [ingreso_total_tienda1, ingreso_total_tienda2, ingreso_total_tienda3, ingreso_total_tienda4]
tiendas_ingresos = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

ingresos_millones = [x / 1_000_000 for x in ingresos_totales]
plt.barh(tiendas_ingresos, ingresos_totales)
plt.ylabel('Tiendas')
plt.xlabel('Ingresos Totales (en millones)')
plt.title('Ingresos Totales por Tienda (Gráfico de Barras)')
# Out:
# Text(0.5, 1.0, 'Ingresos Totales por Tienda (Gráfico de Barras)')

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
ventas_categoria_tienda1 = tienda.groupby(['Categoría del Producto']).size().sort_values(ascending=False)
ventas_categoria_tienda1
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# dtype: int64

# %%
ventas_categoria_tienda2 = tienda2.groupby(['Categoría del Producto']).size().sort_values(ascending=False)
ventas_categoria_tienda2
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# dtype: int64

# %%
ventas_categoria_tienda3 = tienda3.groupby(['Categoría del Producto']).size().sort_values(ascending=False)
ventas_categoria_tienda3
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Artículos para el hogar    177
# Instrumentos musicales     177
# dtype: int64

# %%
ventas_categoria_tienda4 = tienda4.groupby(['Categoría del Producto']).size().sort_values(ascending=False)
ventas_categoria_tienda4
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# dtype: int64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
calificacion_tienda1 = tienda['Calificación'].mean().round(2)
print(f'La calificación promedio de la tienda 1 es {calificacion_tienda1}')
# Out:
# La calificación promedio de la tienda 1 es 3.98

# %%
calificacion_tienda2 = tienda2['Calificación'].mean().round(2)
print(f'La calificación promedio de la tienda 2 es {calificacion_tienda2}')
# Out:
# La calificación promedio de la tienda 2 es 4.04

# %%
calificacion_tienda3 = tienda3['Calificación'].mean().round(2)
print(f'La calificación promedio de la tienda 3 es {calificacion_tienda3}')
# Out:
# La calificación promedio de la tienda 3 es 4.05

# %%
calificacion_tienda4 = tienda4['Calificación'].mean().round(2)
print(f'La calificación promedio de la tienda 4 es {calificacion_tienda4}')
# Out:
# La calificación promedio de la tienda 4 es 4.0

# %%
from matplotlib.lines import lineStyles
calificaciones_totales = [calificacion_tienda1, calificacion_tienda2, calificacion_tienda3, calificacion_tienda4]
tiendas_todas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

plt.plot(tiendas_todas, calificaciones_totales, marker='o', color='b')
plt.ylabel("Calificación")
plt.xlabel("Tiendas")
plt.title("Calificación Promedio por Tienda")
# Out:
# Text(0.5, 1.0, 'Calificación Promedio por Tienda')

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
ventas_tienda1 = tienda['Producto'].value_counts()
max_tienda1 = ventas_tienda1.max()
mas_vendidos = ventas_tienda1[ventas_tienda1 == max_tienda1]
min_tienda1 = ventas_tienda1.min()
menos_vendidos = ventas_tienda1[ventas_tienda1 == min_tienda1]
print(f'El producto más vendido de la tienda 1 es {mas_vendidos}')
print(f'El producto menos vendido de la tienda 1 es {menos_vendidos}')
ventas_tienda1.plot(kind='bar')
# Out:
# El producto más vendido de la tienda 1 es Producto
# Microondas       60
# TV LED UHD 4K    60
# Armario          60
# Name: count, dtype: int64
# El producto menos vendido de la tienda 1 es Producto
# Auriculares con micrófono    33
# Celular ABXY                 33
# Name: count, dtype: int64
# <Axes: xlabel='Producto'>

# %%
ventas_tienda2 = tienda2['Producto'].value_counts()
max_tienda2 = ventas_tienda2.max()
mas_vendidos2 = ventas_tienda2[ventas_tienda2 == max_tienda2]
min_tienda2 = ventas_tienda2.min()
menos_vendidos2 = ventas_tienda2[ventas_tienda2 == min_tienda2]
print(f'El producto más vendido de la tienda 2 es {mas_vendidos2}')
print(f'El producto menos vendido de la tienda 2 es {menos_vendidos2}')
ventas_tienda2.plot(kind='bar')
# Out:
# El producto más vendido de la tienda 2 es Producto
# Iniciando en programación    65
# Name: count, dtype: int64
# El producto menos vendido de la tienda 2 es Producto
# Juego de mesa    32
# Name: count, dtype: int64
# <Axes: xlabel='Producto'>

# %%
ventas_tienda3 = tienda3['Producto'].value_counts()
max_tienda3 = ventas_tienda3.max()
mas_vendidos3 = ventas_tienda3[ventas_tienda3 == max_tienda3]
min_tienda3 = ventas_tienda3.min()
menos_vendidos3 = ventas_tienda3[ventas_tienda3 == min_tienda3]
print(f'El producto más vendido de la tienda 3 es {mas_vendidos3}')
print(f'El producto menos vendido de la tienda 3 es {menos_vendidos3}')
ventas_tienda3.plot(kind='bar')
# Out:
# El producto más vendido de la tienda 3 es Producto
# Kit de bancas    57
# Name: count, dtype: int64
# El producto menos vendido de la tienda 3 es Producto
# Bloques de construcción    35
# Name: count, dtype: int64
# <Axes: xlabel='Producto'>

# %%
ventas_tienda4 = tienda4['Producto'].value_counts()
max_tienda4 = ventas_tienda4.max()
mas_vendidos4 = ventas_tienda4[ventas_tienda4 == max_tienda4]
min_tienda4 = ventas_tienda4.min()
menos_vendidos4 = ventas_tienda4[ventas_tienda4 == min_tienda4]
print(f'El producto más vendido de la tienda 4 es {mas_vendidos4}')
print(f'El producto menos vendido de la tienda 4 es {menos_vendidos4}')
ventas_tienda4.plot(kind='bar')
# Out:
# El producto más vendido de la tienda 4 es Producto
# Cama box    62
# Name: count, dtype: int64
# El producto menos vendido de la tienda 4 es Producto
# Guitarra eléctrica    33
# Name: count, dtype: int64
# <Axes: xlabel='Producto'>

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.  Sabiendo que el cliente paga el envío.

# %%
envio_promedio_tienda1 = tienda['Costo de envío'].mean().round(2)
print(f'El costo de envío promedio para la tienda 1 es {envio_promedio_tienda1}')
# Out:
# El costo de envío promedio para la tienda 1 es 26018.61

# %%
envio_promedio_tienda2 = tienda2['Costo de envío'].mean().round(2)
print(f'El costo de envío promedio para la tienda 2 es {envio_promedio_tienda2}')
# Out:
# El costo de envío promedio para la tienda 2 es 25216.24

# %%
envio_promedio_tienda3 = tienda3['Costo de envío'].mean().round(2)
print(f'El costo de envío promedio para la tienda 3 es {envio_promedio_tienda3}')
# Out:
# El costo de envío promedio para la tienda 3 es 24805.68

# %%
envio_promedio_tienda4 = tienda4['Costo de envío'].mean().round(2)
print(f'El costo de envío promedio para la tienda 4 es {envio_promedio_tienda4}')
# Out:
# El costo de envío promedio para la tienda 4 es 23459.46

# %%
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
costos_envio_promedio = [envio_promedio_tienda1, envio_promedio_tienda2, envio_promedio_tienda3, envio_promedio_tienda4]
plt.pie(costos_envio_promedio, labels=tiendas, autopct='%1.1f%%')
plt.title('Distribución del Costo de Envío Promedio por Tienda')
# Out:
# Text(0.5, 1.0, 'Distribución del Costo de Envío Promedio por Tienda')

# %% [markdown]
# ## **Informe Final**

# %% [markdown]
# El objetivo de este informe es analizar y mostrar el desempeño de las 4 tiendas del Sr. Juan debe vender con fin de hacer un nuevo emprendimiento. Estos analisis están hechos considerando diversos indicadores claves como lo son: los ingresos totales, las categorías con mayor y menor venta, calificaciones promedios otorgadas por los clientes, los productos más y menos vendidos y por último el costo de envío promedio.

# %% [markdown]
# Al empezar a analizar los datos, lo primero que noté fue que la tienda 4 que tiene como ingresos totales: 1,038,375,700.00 es la que menos tiene de todas, representando menor demanda o menor volumen de ventas, este es de los indicadores más importantes ya que refleja la rentabilidad del negocio.

# %% [markdown]
# ![barras.png](data:image/png;base64,...)
# Gráfica de barras realizada en "1. Análisis de facturación" que muestra las 4 tiendas y podemos observar que la Tienda 4 es la de menor desempeño.

# %% [markdown]
# El segun factor más clave a mi parecer: las calificaciones promedio otorgadas por los clientes.
# Una mayor satisfacción se puede decir que es una mayor fidelización, lealtad y recomendaciones por parte de los clientes, por lo que la tienda con mayor calificación podemos considerarla la mas apta hasta el momento, pero en esta ocasión hablare de la más baja, la que menos rendimiento tuvo, en este caso fue la tienda 1 con una calificación promedio de 3.98.
# Pero con los datos que tenemos debemos observar a la tienda 4 (ya que fue la que menos desempeño tuvo en los ingresos totales) y tiene una calificación de 4.0, siendo la segunda más baja de todas, lo que es un punto muy importante ya que analizando las combinaciones lleva:
# La tienda con menor ingreso total y la segunda tienda peor calificada, su percepción de calidad no es destacada por los clientes.
# ![grafica_puntos.png](data:image/png;base64,...)

# %% [markdown]
# Respecto a los productos más vendidos, en la tienda 4 es la Cama Box con 62 ventas, tiene un buen desempeño pero no es el más vendido de todas las tiendas, siendo superada por la tienda 2 (con 65 ventas), la tienda 4 cuenta con algunos productos que pueden ser competitivos pero aún así no logra posicionarse como la mejor opción, esto pudiendo demostrar falta de liderazgo en el mercado.

# %% [markdown]
# Por último donde si destaca la tienda 4 es que tiene para ofrecer el menor costo de envío promedio al cliente (23,459.46) pero la tienda 4 no logra convertir esta ventaja en mayores ingresos por lo tanto no representa una ventaja financiera significativa para la tienda.

# %% [markdown]
# ## Conclusión

# %% [markdown]
# Basado en todo el análisis anterior: la tienda 4 es la menos eficiente en términos generales específicamente en los ingresos totales y no puede compensar esta situación con ventajas competitivas precisas.
# Por esto se recomienda al Sr. Juan vender la tienda 4 siendo esta la decisión más estratégica para optimizar su dinero y tener posibilidad de emprender en otro negocio.
